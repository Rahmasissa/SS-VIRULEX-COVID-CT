# %% [markdown]
# # 01 - Image Augmentation Code on COVID-CT

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
official = build_official_split_table()
print("Official split counts:")
print(official.groupby(["split", "class_name"]).size().unstack(fill_value=0))
# Out:
# Official split counts:
# class_name  COVID  NonCOVID
# split
# test           98       105
# train         191       234
# val            60        58

# %%
augmented = create_augmented_manifest()
print("Augmented split counts:")
print(augmented.groupby(["split", "class_name", "source"]).size())
print("Saved:", OUTPUT_DIR / "01_augmented_splits.csv")
# Out:
# Augmented split counts:
# split  class_name  source
# test   COVID       original      98
#        NonCOVID    original     105
# train  COVID       augmented    277
#                    original     191
#        NonCOVID    augmented    234
#                    original     234
# val    COVID       original      60
#        NonCOVID    original      58
# dtype: int64
# Saved: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/01_augmented_splits.csv
