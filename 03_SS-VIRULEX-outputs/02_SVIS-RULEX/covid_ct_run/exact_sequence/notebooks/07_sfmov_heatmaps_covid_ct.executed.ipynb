# %% [markdown]
# # 07 - SFMOV Heatmaps on COVID-CT

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
saved = run_sfmov_heatmaps(samples_per_class=4)
print("Saved heatmap files:")
for path in saved:
    print(path)
# Out:
# Saved heatmap files:
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41%5_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41%5_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41%5_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41%5_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_bmj.m606.full-p4-22%2_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_bmj.m606.full-p4-22%2_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_bmj.m606.full-p4-22%2_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_bmj.m606.full-p4-22%2_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12%3_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12%3_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12%3_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12%3_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_2020.03.26.20041426-p11-120_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_2020.03.26.20041426-p11-120_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_2020.03.26.20041426-p11-120_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/COVID_2020.03.26.20041426-p11-120_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_5%4_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_5%4_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_5%4_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_5%4_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_663_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_663_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_663_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_663_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_1211_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_1211_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_1211_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_1211_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_849_mean.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_849_skewness.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_849_entropy.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/heatmaps/NonCOVID_849_combined.png
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:798: UserWarning: Skipping variable loading for optimizer 'adam', because it has 22 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
metric_summary = final_sequence_summary()
print(metric_summary.to_string(index=False))
# Out:
#                         stage  accuracy  balanced_accuracy  f1_weighted  roc_auc
#   custom_mobilenetv2_complete  0.704433           0.704422     0.704505 0.790282
# best_decision_tree_selected_6  0.561576           0.554422     0.541457 0.547522
#       best_rulefit_selected_3  0.507389           0.508844     0.506671      NaN
