# %% [markdown]
# # 05b - RuleFit GridSearch Code on COVID-CT Statistical Features

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
results = evaluate_rulefit_grid()
print(results.to_string(index=False))
# Out:
# {'feature_set': 'selected_3', 'n_features': 3, 'best_params': '{"tree_size": 4, "sample_fract": 0.8, "max_rules": 50}', 'val_balanced_accuracy': 0.524712643678161, 'test_accuracy': 0.5073891625615764, 'test_balanced_accuracy': 0.508843537414966, 'test_f1_weighted': 0.5066714894301101, 'confusion_matrix': '[[49, 56], [44, 54]]', 'n_nonzero_rules': 7, 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05b_rulefit_selected_3_rules.csv'}
# feature_set  n_features                                            best_params  val_balanced_accuracy  test_accuracy  test_balanced_accuracy  test_f1_weighted     confusion_matrix  n_nonzero_rules                                                                                                                                    rules_path
#  selected_3           3 {"tree_size": 4, "sample_fract": 0.8, "max_rules": 50}               0.524713       0.507389                0.508844          0.506671 [[49, 56], [44, 54]]                7 /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05b_rulefit_selected_3_rules.csv
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1811: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' instead. Use l1_ratios=(0,) instead of penalty='l2'  and l1_ratios=(1,) instead of penalty='l1'.
#   warnings.warn(
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
