# %% [markdown]
# # 02 - DL Model Hyperparameter Optimization Using Grid Search

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
augmented = load_augmented_splits()
print("Input split counts:")
print(augmented.groupby(["split", "class_name"]).size().unstack(fill_value=0))
# Out:
# Input split counts:
# class_name  COVID  NonCOVID
# split
# test           98       105
# train         468       468
# val            60        58

# %%
results, best_params = run_dl_grid_search()
print("Best hyperparameters:")
print(best_params)
print(results.to_string(index=False))
# Out:
# train (936, 1280) (936,)
# val (118, 1280) (118,)
# test (203, 1280) (203,)
# {'learning_rate': 0.001, 'dense_units': 128, 'dropout': 0.3, 'epochs_run': 6, 'seconds': 8.059299230575562, 'val_accuracy': 0.559322033898305, 'val_balanced_accuracy': 0.5629310344827586, 'val_f1_weighted': 0.5387209662591489, 'val_roc_auc': 0.6043103448275862}
# {'learning_rate': 0.001, 'dense_units': 128, 'dropout': 0.5, 'epochs_run': 5, 'seconds': 6.51330304145813, 'val_accuracy': 0.576271186440678, 'val_balanced_accuracy': 0.5767241379310345, 'val_f1_weighted': 0.5760276641340348, 'val_roc_auc': 0.646551724137931}
# {'learning_rate': 0.001, 'dense_units': 256, 'dropout': 0.3, 'epochs_run': 5, 'seconds': 6.815800905227661, 'val_accuracy': 0.5847457627118644, 'val_balanced_accuracy': 0.5839080459770114, 'val_f1_weighted': 0.5836982745457321, 'val_roc_auc': 0.646551724137931}
# {'learning_rate': 0.001, 'dense_units': 256, 'dropout': 0.5, 'epochs_run': 5, 'seconds': 7.429949998855591, 'val_accuracy': 0.576271186440678, 'val_balanced_accuracy': 0.57816091954023, 'val_f1_weighted': 0.5711052618631768, 'val_roc_auc': 0.6123563218390805}
# {'learning_rate': 0.0003, 'dense_units': 128, 'dropout': 0.3, 'epochs_run': 7, 'seconds': 8.766897201538086, 'val_accuracy': 0.6186440677966102, 'val_balanced_accuracy': 0.6229885057471264, 'val_f1_weighted': 0.5924391466737142, 'val_roc_auc': 0.6330459770114942}
# {'learning_rate': 0.0003, 'dense_units': 128, 'dropout': 0.5, 'epochs_run': 5, 'seconds': 7.946079969406128, 'val_accuracy': 0.5084745762711864, 'val_balanced_accuracy': 0.5089080459770114, 'val_f1_weighted': 0.5081920903954802, 'val_roc_auc': 0.5382183908045977}
# {'learning_rate': 0.0003, 'dense_units': 256, 'dropout': 0.3, 'epochs_run': 5, 'seconds': 13.810364246368408, 'val_accuracy': 0.5508474576271186, 'val_balanced_accuracy': 0.5525862068965517, 'val_f1_weighted': 0.5461942073511408, 'val_roc_auc': 0.589367816091954}
# {'learning_rate': 0.0003, 'dense_units': 256, 'dropout': 0.5, 'epochs_run': 5, 'seconds': 7.745528936386108, 'val_accuracy': 0.5847457627118644, 'val_balanced_accuracy': 0.5873563218390805, 'val_f1_weighted': 0.5749087903140596, 'val_roc_auc': 0.6603448275862068}
# Best hyperparameters:
# {'learning_rate': 0.0003, 'dense_units': 128, 'dropout': 0.3}
#  learning_rate  dense_units  dropout  epochs_run   seconds  val_accuracy  val_balanced_accuracy  val_f1_weighted  val_roc_auc
#         0.0003          128      0.3           7  8.766897      0.618644               0.622989         0.592439     0.633046
#         0.0003          256      0.5           5  7.745529      0.584746               0.587356         0.574909     0.660345
#         0.0010          256      0.3           5  6.815801      0.584746               0.583908         0.583698     0.646552
#         0.0010          256      0.5           5  7.429950      0.576271               0.578161         0.571105     0.612356
#         0.0010          128      0.5           5  6.513303      0.576271               0.576724         0.576028     0.646552
#         0.0010          128      0.3           6  8.059299      0.559322               0.562931         0.538721     0.604310
#         0.0003          256      0.3           5 13.810364      0.550847               0.552586         0.546194     0.589368
#         0.0003          128      0.5           5  7.946080      0.508475               0.508908         0.508192     0.538218
# Matplotlib is building the font cache; this may take a moment.
# WARNING:tensorflow:5 out of the last 20 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x140521440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x1406aa020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
