# %% [markdown]
# # 04 - Statistical Features Extraction and Feature Selection Using ZFMIS

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
feature_sets = run_statistical_features_zfmis()
for name, columns in feature_sets.items():
    print(name, len(columns), columns)
print("Saved feature sets:", FEATURE_DIR / "04_zfmis_feature_sets.json")
# Out:
# train (936, 128)
# val (118, 128)
# test (203, 128)
# all 26 ['mean', 'std_dev', 'variance', 'median', 'range', 'skewness', 'kurtosis', 'entropy', 'energy', 'contrast', 'mean_abs_dev', 'min_value', 'max_value', 'iqr', 'percentile_25', 'percentile_50', 'percentile_75', 'signal_to_noise', 'coef_of_var', 'autocorrelation', 'shannon_entropy', 'root_mean_square', 'harmonic_mean', 'geometric_mean', 'std_error_mean', 'median_abs_dev']
# filtered 21 ['std_error_mean', 'geometric_mean', 'harmonic_mean', 'root_mean_square', 'shannon_entropy', 'autocorrelation', 'coef_of_var', 'signal_to_noise', 'percentile_75', 'mean', 'std_dev', 'max_value', 'mean_abs_dev', 'contrast', 'energy', 'entropy', 'kurtosis', 'skewness', 'range', 'variance', 'iqr']
# selected_18 18 ['std_error_mean', 'geometric_mean', 'harmonic_mean', 'root_mean_square', 'shannon_entropy', 'coef_of_var', 'signal_to_noise', 'percentile_75', 'mean', 'std_dev', 'max_value', 'mean_abs_dev', 'contrast', 'energy', 'entropy', 'range', 'variance', 'iqr']
# selected_15 15 ['std_error_mean', 'geometric_mean', 'harmonic_mean', 'root_mean_square', 'shannon_entropy', 'coef_of_var', 'signal_to_noise', 'percentile_75', 'std_dev', 'mean_abs_dev', 'contrast', 'energy', 'entropy', 'variance', 'iqr']
# selected_12 12 ['std_error_mean', 'geometric_mean', 'shannon_entropy', 'coef_of_var', 'signal_to_noise', 'percentile_75', 'std_dev', 'mean_abs_dev', 'contrast', 'entropy', 'variance', 'iqr']
# selected_9 9 ['geometric_mean', 'shannon_entropy', 'coef_of_var', 'signal_to_noise', 'percentile_75', 'std_dev', 'mean_abs_dev', 'entropy', 'iqr']
# selected_6 6 ['geometric_mean', 'shannon_entropy', 'coef_of_var', 'signal_to_noise', 'mean_abs_dev', 'entropy']
# selected_3 3 ['shannon_entropy', 'coef_of_var', 'entropy']
# Saved feature sets: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/features/04_zfmis_feature_sets.json
# /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/.venv/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:798: UserWarning: Skipping variable loading for optimizer 'adam', because it has 22 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
