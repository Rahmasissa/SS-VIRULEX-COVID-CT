# %% [markdown]
# # 05a - GridSearchForTree on COVID-CT Statistical Features

# %%
import sys
from pathlib import Path

SCRIPT_DIR = Path("/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/scripts")
if str(SCRIPT_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPT_DIR))

from common import *
setup_environment()
print("Run root:", RUN_ROOT)
print("Output dir:", OUTPUT_DIR)
# Out:
# Run root: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence
# Output dir: /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs

# %%
results = evaluate_tree_grid()
print(results.to_string(index=False))
# Out:
# {'feature_set': 'all', 'n_features': 26, 'best_params': '{"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 8, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.6209791809654541, 'test_accuracy': 0.5221674876847291, 'test_balanced_accuracy': 0.5241496598639456, 'test_f1_weighted': 0.5207738821074334, 'test_roc_auc': 0.5589893100097182, 'confusion_matrix': '[[49, 56], [41, 57]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_all.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_all_rules.txt'}
# {'feature_set': 'filtered', 'n_features': 21, 'best_params': '{"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 8, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.6209791809654541, 'test_accuracy': 0.5221674876847291, 'test_balanced_accuracy': 0.5241496598639456, 'test_f1_weighted': 0.5207738821074334, 'test_roc_auc': 0.5589893100097182, 'confusion_matrix': '[[49, 56], [41, 57]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_filtered.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_filtered_rules.txt'}
# {'feature_set': 'selected_18', 'n_features': 18, 'best_params': '{"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 1, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.599290780141844, 'test_accuracy': 0.5024630541871922, 'test_balanced_accuracy': 0.503061224489796, 'test_f1_weighted': 0.5024630541871922, 'test_roc_auc': 0.533041788143829, 'confusion_matrix': '[[51, 54], [47, 51]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_18.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_18_rules.txt'}
# {'feature_set': 'selected_15', 'n_features': 15, 'best_params': '{"criterion": "entropy", "max_depth": 4, "min_samples_leaf": 2, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.5929535575383207, 'test_accuracy': 0.5517241379310345, 'test_balanced_accuracy': 0.5452380952380952, 'test_f1_weighted': 0.5350182051831227, 'test_roc_auc': 0.5465014577259475, 'confusion_matrix': '[[77, 28], [63, 35]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_15.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_15_rules.txt'}
# {'feature_set': 'selected_12', 'n_features': 12, 'best_params': '{"criterion": "entropy", "max_depth": 2, "min_samples_leaf": 1, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.5914207275223061, 'test_accuracy': 0.541871921182266, 'test_balanced_accuracy': 0.5357142857142857, 'test_f1_weighted': 0.5266044551003298, 'test_roc_auc': 0.5354227405247813, 'confusion_matrix': '[[75, 30], [63, 35]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_12.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_12_rules.txt'}
# {'feature_set': 'selected_9', 'n_features': 9, 'best_params': '{"criterion": "entropy", "max_depth": 2, "min_samples_leaf": 1, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.5914207275223061, 'test_accuracy': 0.541871921182266, 'test_balanced_accuracy': 0.5357142857142857, 'test_f1_weighted': 0.5266044551003298, 'test_roc_auc': 0.5354227405247813, 'confusion_matrix': '[[75, 30], [63, 35]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_9.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_9_rules.txt'}
# {'feature_set': 'selected_6', 'n_features': 6, 'best_params': '{"criterion": "entropy", "max_depth": 4, "min_samples_leaf": 8, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.5964767787691604, 'test_accuracy': 0.5615763546798029, 'test_balanced_accuracy': 0.5544217687074829, 'test_f1_weighted': 0.5414568442890826, 'test_roc_auc': 0.5475218658892128, 'confusion_matrix': '[[80, 25], [64, 34]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_6.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_6_rules.txt'}
# {'feature_set': 'selected_3', 'n_features': 3, 'best_params': '{"criterion": "gini", "max_depth": 2, "min_samples_leaf": 4, "min_samples_split": 2}', 'cv_balanced_accuracy': 0.5887096774193548, 'test_accuracy': 0.5073891625615764, 'test_balanced_accuracy': 0.508843537414966, 'test_f1_weighted': 0.5066714894301101, 'test_roc_auc': 0.508843537414966, 'confusion_matrix': '[[49, 56], [44, 54]]', 'model_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_3.pkl', 'rules_path': '/Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_3_rules.txt'}
# feature_set  n_features                                                                             best_params  cv_balanced_accuracy  test_accuracy  test_balanced_accuracy  test_f1_weighted  test_roc_auc     confusion_matrix                                                                                                                                      model_path                                                                                                                                           rules_path
#  selected_6           6 {"criterion": "entropy", "max_depth": 4, "min_samples_leaf": 8, "min_samples_split": 2}              0.596477       0.561576                0.554422          0.541457      0.547522 [[80, 25], [64, 34]]  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_6.pkl  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_6_rules.txt
# selected_15          15 {"criterion": "entropy", "max_depth": 4, "min_samples_leaf": 2, "min_samples_split": 2}              0.592954       0.551724                0.545238          0.535018      0.546501 [[77, 28], [63, 35]] /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_15.pkl /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_15_rules.txt
# selected_12          12 {"criterion": "entropy", "max_depth": 2, "min_samples_leaf": 1, "min_samples_split": 2}              0.591421       0.541872                0.535714          0.526604      0.535423 [[75, 30], [63, 35]] /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_12.pkl /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_12_rules.txt
#  selected_9           9 {"criterion": "entropy", "max_depth": 2, "min_samples_leaf": 1, "min_samples_split": 2}              0.591421       0.541872                0.535714          0.526604      0.535423 [[75, 30], [63, 35]]  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_9.pkl  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_9_rules.txt
#         all          26 {"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 8, "min_samples_split": 2}              0.620979       0.522167                0.524150          0.520774      0.558989 [[49, 56], [41, 57]]         /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_all.pkl         /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_all_rules.txt
#    filtered          21 {"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 8, "min_samples_split": 2}              0.620979       0.522167                0.524150          0.520774      0.558989 [[49, 56], [41, 57]]    /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_filtered.pkl    /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_filtered_rules.txt
#  selected_3           3    {"criterion": "gini", "max_depth": 2, "min_samples_leaf": 4, "min_samples_split": 2}              0.588710       0.507389                0.508844          0.506671      0.508844 [[49, 56], [44, 54]]  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_3.pkl  /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_3_rules.txt
# selected_18          18 {"criterion": "entropy", "max_depth": 3, "min_samples_leaf": 1, "min_samples_split": 2}              0.599291       0.502463                0.503061          0.502463      0.533042 [[51, 54], [47, 51]] /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/models/05a_decision_tree_selected_18.pkl /Users/samehissa/Downloads/XAI-Med-Images-Stat-Visual-Rules-main 2/covid_ct_run/exact_sequence/outputs/rules/05a_decision_tree_selected_18_rules.txt
